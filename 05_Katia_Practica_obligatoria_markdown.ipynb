# %% [markdown]
# ![TheBridge_logo_RGB_color.jpg](attachment:TheBridge_logo_RGB_color.jpg)

# %% [markdown]
# ![ejercicios.png](attachment:ejercicios.png)

# %% [markdown]
# # Markdown Práctica Obligatoria
#
# ## Ejercicio 1
# Vamos a aplicar los conocimientos adquiridos en este notebook, intentando reproducir la siguiente imagen en una celda markdown con su sintaxis. En el link que va enlazado a ``página con ML``es:``https://www.kaggle.com/``
#
# **TIP**: en [este enlace](https://www.markdownguide.org/basic-syntax/) tienes más ejemplos, por si te atascas con algo :)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <div style="background-color: #2e2d29; padding: 15px; margin-top: -20px; margin-bottom: -20px;">
#
# <h3 style="color: #c2c0ba; font-weight: bold;">Lo más importante</h3>
#
#
# <ul style="color: #c2c0ba;">
#   <li>Matemáticas</li>
#   <li>Python</li>
#   <li>SQL</li>
# </ul>
#
# <img src="attachment:975a3fa4-ddbf-4ab9-9cab-58faaec7c2f7.png" alt="Python-logo" width="300" height="200" style="margin-left: 20px;"/>
#
# <span style="color:#c2c0ba">Otro tema importante es el de *Business Intelligence*</span>
#
# <span style="color:#c2c0ba">Si tienes dudas, puedes escribirme a:
# <a href="mailto:alberto.romero@thebridgeschool.es" style="color:#379ad4;">alberto.romero@thebridgeschool.es</a>
# </span>
#
#
# <span style="color:#c2c0ba">Y en esta página se aprende mucho de machine learning:
# <a href="https://www.kaggle.com/" style="color:#379ad4;"><strong>página con ML</strong></a></span>

# %% [markdown]
# ## Ejercicio 2
# Para este ejercicio vas a crear dos nuevos elementos que no hemos visto en la teoría, tendrás que buscar en google cómo hacer: una tabla y una fórmula. Busca en la web la sintaxis y replica ambos elementos.(no es necesaria la tira azul)

# %% [markdown]
# ![md_ejercicio2.png](attachment:md_ejercicio2.png)

# %% [markdown]
# | **Ramp Up** | **Data Analysis** | **Machine Learning** | **Data & Business** |
# |-------------|-------------------|----------------------|---------------------|
# | Python | EDA | Supervised | Productivización |
# | Estadística | R | Non supervised | Storytelling |
# | SQL | Feat. Eng. | Deap learning | API |

# %% [markdown]
# $\sqrt{3x - 1} + (1 + x)^n$
